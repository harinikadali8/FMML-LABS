# %% [markdown]
# <a href="https://colab.research.google.com/github/harinikadali8/FMML-LABS/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-01 05:11:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  52.7MB/s    in 1.3s
#
# 2025-04-01 05:11:15 (52.7 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 1703 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 138  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 13  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12069  1707.03821v1  We introduce a methodology for efficient monit...    cs
# 24721   1411.2090v1  In this paper, we present feature-based techni...    cs
# 11348  1510.07025v2  Collaborative filtering analyzes user preferen...  stat
# 9294   1712.08969v1  We study randomly initialized residual network...    cs
# 27526  1703.09554v3  Convolutional networks reach top quality in pi...    cs
# ...             ...                                                ...   ...
# 36240  1604.03468v1  In this paper we address planning problems in ...    cs
# 172    1711.03637v1  We describe a novel spiking neural network (SN...  stat
# 9011   1702.00564v2  We present a case-study demonstrating the usef...  stat
# 25773  1511.06214v2  Minimisation of discrete energies defined over...    cs
# 33773  1701.08951v1  This paper proposes a hybrid technique for sec...    cs
#
#                                                    title  year  \
# 12069  Process Monitoring on Sequences of System Call...  2017
# 24721  Parallax Effect Free Mosaicing of Underwater V...  2014
# 11348           Modeling User Exposure in Recommendation  2015
# 9294   Mean Field Residual Networks: On the Edge of C...  2017
# 27526   Lucid Data Dreaming for Multiple Object Tracking  2017
# ...                                                  ...   ...
# 36240  Backward-Forward Search for Manipulation Planning  2016
# 172    Learning and Real-time Classification of Hand-...  2017
# 9011   Modelling dependency completion in sentence co...  2017
# 25773  Automatically selecting inference algorithms f...  2015
# 33773  A Hybrid Approach for Secured Optimal Power Fl...  2017
#
#                                                 keywords
# 12069                                   [characterizing]
# 24721                                  [correspondences]
# 11348                                   [recommendation]
# 9294   [subexponential, subexponential, hyperparamete...
# 27526                                                 []
# ...                                                  ...
# 36240                [identification, probabilistically]
# 172    [classification, implementation, classificatio...
# 9011                                                  []
# 25773                                   [experimentally]
# 33773                                                 []
#
# [4891 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12069                                     [characterizing]
# 24721                                    [correspondences]
# 11348                                     [recommendation]
# 9294     [subexponential, subexponential, hyperparamete...
# 27526                                                   []
#                                ...
# 21962                     [bioinformatics, generalization]
# 36999                                    [correspondences]
# 24282                                                   []
# 7423                      [experimentally, generalization]
# 8777                                      [conversational]
# Name: keywords, Length: 6114, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 1119 words.
# Out of those 10 have over 138 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="295924eb-9c8c-487b-8b78-42dae1267d21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("295924eb-9c8c-487b-8b78-42dae1267d21")) {                    Plotly.newPlot(                        "295924eb-9c8c-487b-8b78-42dae1267d21",                        [{"x":["classification","representations","implementation","representation","computationally","regularization","identification","generalization","dimensionality","simultaneously"],"y":[526,236,130,345,85,78,106,114,47,96],"type":"bar"},{"x":["classification","representations","implementation","representation","computationally","regularization","identification","generalization","dimensionality","simultaneously"],"y":[398,116,80,174,156,144,59,138,96,89],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (10,), (10, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.4897792313982011

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Kannada</span> <span style=''>named</span> <span style=''>entity</span> <span style=''>recognition</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>(nerc)</span> <span style=''>based</span> <span style=''>on</span> <span style=''>multinomial</span> <span style=''>naïve</span> <span style=''>bayes</span> <span style=''>(mnb)</span> <span style=''>classifier</span> <br/><br/><span style=''>Named</span> <span style=''>Entity</span> <span style=''>Recognition</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style=''>(NERC)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>process</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identification</span> <span style=''>of</span> <span style=''>proper</span> <span style=''>nouns</span> <span style=''>in</span> <span style=''>the</span> <span style=''>text</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>those</span> <span style=''>nouns</span> <span style=''>into</span> <span style=''>certain</span> <span style=''>predefined</span> <span style=''>categories</span> <span style=''>like</span> <span style=''>person</span> <span style=''>name</span> <span style=''>location</span> <span style=''>organization</span> <span style=''>date</span> <span style=''>and</span> <span style=''>time</span> <span style=''>etc</span> <span style=''>NERC</span> <span style=''>in</span> <span style=''>Kannada</span> <span style=''>is</span> <span style=''>an</span> <span style=''>essential</span> <span style=''>and</span> <span style=''>challenging</span> <span style=''>task</span> <span style=''>The</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>this</span> <span style=''>work</span> <span style=''>is</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>model</span> <span style=''>for</span> <span style=''>NERC</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Multinomial</span> <span style=''>Naive</span> <span style=''>Bayes</span> <span style=''>(MNB)</span> <span style=''>Classifier</span> <span style=''>The</span> <span style=''>Methodology</span> <span style=''>adopted</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>feature</span> <span style=''>extraction</span> <span style=''>of</span> <span style=''>training</span> <span style=''>corpus</span> <span style=''>by</span> <span style=''>using</span> <span style=''>term</span> <span style=''>frequency</span> <span style=''>inverse</span> <span style=''>document</span> <span style=''>frequency</span> <span style=''>and</span> <span style=''>fitting</span> <span style=''>them</span> <span style=''>to</span> <span style=''>a</span> <span style=''>tf</span> <span style=''>idf</span> <span style=''>vectorizer</span> <span style=''>The</span> <span style=''>paper</span> <span style=''>discusses</span> <span style=''>the</span> <span style=''>various</span> <span style=''>issues</span> <span style=''>in</span> <span style=''>developing</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>The</span> <span style=''>details</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>and</span> <span style=''>performance</span> <span style=''>evaluation</span> <span style=''>are</span> <span style=''>discussed</span> <span style=''>The</span> <span style=''>experiments</span> <span style=''>are</span> <span style=''>conducted</span> <span style=''>on</span> <span style=''>a</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Spectral</span> <span style=''>Norm</span> <span style=''>of</span> <span style=''>Random</span> <span style=''>Kernel</span> <span style=''>Matrices</span> <span style=''>with</span> <span style=''>Applications</span> <span style=''>to</span> <span style=''>Privacy</span> <br/><br/><span style=''>Kernel</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>an</span> <span style=''>extremely</span> <span style=''>popular</span> <span style=''>set</span> <span style=''>of</span> <span style=''>techniques</span> <span style=''>used</span> <span style=''>for</span> <span style=''>many</span> <span style=''>important</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>applications</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>having</span> <span style=''>good</span> <span style=''>practical</span> <span style=''>performances</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>supported</span> <span style=''>by</span> <span style=''>a</span> <span style=''>well</span> <span style=''>developed</span> <span style=''>theory</span> <span style=''>Kernel</span> <span style=''>methods</span> <span style=''>use</span> <span style=''>an</span> <span style=''>implicit</span> <span style=''>mapping</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>data</span> <span style=''>into</span> <span style=''>a</span> <span style=''>high</span> <span style=''>dimensional</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>ie</span> <span style=''>a</span> <span style=''>function</span> <span style=''>returning</span> <span style=''>the</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>between</span> <span style=''>the</span> <span style=''>images</span> <span style=''>of</span> <span style=''>two</span> <span style=''>data</span> <span style=''>points</span> <span style=''>in</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>Central</span> <span style=''>to</span> <span style=''>any</span> <span style=''>kernel</span> <span style=''>method</span> <span style=''>is</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>matrix</span> <span style=''>which</span> <span style=''>is</span> <span style=''>built</span> <span style=''>by</span> <span style=''>evaluating</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>on</span> <span style=''>a</span> <span style=''>given</span> <span style=''>sample</span> <span style=''>dataset</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>initiate</span> <span style=''>the</span> <span style=''>study</span> <span style=''>of</span> <span style=''>non</span> <span style=''>asymptotic</span> <span style=''>spectral</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>random</span> <span style=''>kernel</span> <span style=''>matrices</span> <span style=''>These</span> <span style=''>are</span> <span style=''>n</span> <span style=''>x</span> <span style=''>n</span> <span style=''>random</span> <span style=''>matrices</span> <span style=''>whose</span> <span style=''>(ij)th</span> <span style=''>entry</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>evaluating</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>on</span> <span style=''>x</span> <span style=''>i</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Lambek</span> <span style=''>grammars</span> <span style=''>from</span> <span style=''>proof</span> <span style=''>frames</span> <br/><br/><span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>their</span> <span style=''>limpid</span> <span style=''>interface</span> <span style=''>with</span> <span style=''>semantics</span> <span style=''>categorial</span> <span style=''>grammars</span> <span style=''>enjoy</span> <span style=''>another</span> <span style=''>important</span> <span style=''>property</span> <span style=''>learnability</span> <span style=''>This</span> <span style=''>was</span> <span style=''>first</span> <span style=''>noticed</span> <span style=''>by</span> <span style=''>Buskowsky</span> <span style=''>and</span> <span style=''>Penn</span> <span style=''>and</span> <span style=''>further</span> <span style=''>studied</span> <span style=''>by</span> <span style=''>Kanazawa</span> <span style=''>for</span> <span style=''>Bar</span> <span style=''>Hillel</span> <span style=''>categorial</span> <span style=''>grammars</span> <span style=''>What</span> <span style=''>about</span> <span style=''>Lambek</span> <span style=''>categorial</span> <span style=''>grammars</span> <span style=''>In</span> <span style=''>a</span> <span style=''>previous</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>showed</span> <span style=''>that</span> <span style=''>product</span> <span style=''>free</span> <span style=''>Lambek</span> <span style=''>grammars</span> <span style=''>where</span> <span style=''>learnable</span> <span style=''>from</span> <span style=''>structured</span> <span style=''>sentences</span> <span style=''>the</span> <span style=''>structures</span> <span style=''>being</span> <span style=''>incomplete</span> <span style=''>natural</span> <span style=''>deductions</span> <span style=''>These</span> <span style=''>grammars</span> <span style=''>were</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style=''>unlearnable</span> <span style=''>from</span> <span style=''>strings</span> <span style=''>by</span> <span style=''>Foret</span> <span style=''>and</span> <span style=''>Le</span> <span style=''>Nir</span> <span style=''>In</span> <span style=''>the</span> <span style=''>present</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>Lambek</span> <span style=''>grammars</span> <span style=''>possibly</span> <span style=''>with</span> <span style=''>product</span> <span style=''>are</span> <span style=''>learnable</span> <span style=''>from</span> <span style=''>proof</span> <span style=''>frames</span> <span style=''>that</span> <span style=''>are</span> <span style=''>incomplete</span> <span style=''>proof</span> <span style=''>nets</span> <span style=''>After</span> <span style=''>a</span> <span style=''>short</span> <span style=''>reminder</span> <span style=''>on</span> <span style=''>grammatical</span> <span style=''>inference</span> <span style=''>a</span> <span style=''>la</span> <span style=''>Gold</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>an</span> <span style=''>algorithm</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>Lambek</span> <span style=''>grammars</span> <span style=''>with</span> <span style=''>product</span> <span style=''>from</span> <span style=''>proof</span> <span style=''>frames</span> <span style=''>and</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>its</span> <span style=''>convergence</span> <span style=''>We</span> <span style=''>do</span> <span style=''>so</span> <span style=''>for</span> <span style=''>1</span> <span style=''>valued</span> <span style=''>also</span> <span style=''>known</span> <span style=''>as</span> <span style=''>rigid</span> <span style=''>La ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Predictive</span> <span style=''>Active</span> <span style=''>Set</span> <span style=''>Selection</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Processes</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>active</span> <span style=''>set</span> <span style=''>selection</span> <span style=''>framework</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>for</span> <span style=''>cases</span> <span style=''>when</span> <span style=''>the</span> <span style=''>dataset</span> <span style=''>is</span> <span style=''>large</span> <span style=''>enough</span> <span style=''>to</span> <span style=''>render</span> <span style=''>its</span> <span style=''>inference</span> <span style=''>prohibitive</span> <span style=''>Our</span> <span style=''>scheme</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>a</span> <span style=''>two</span> <span style=''>step</span> <span style=''>alternating</span> <span style=''>procedure</span> <span style=''>of</span> <span style=''>active</span> <span style=''>set</span> <span style=''>update</span> <span style=''>rules</span> <span style=''>and</span> <span style=''>hyperparameter</span> <span style=''>optimization</span> <span style=''>based</span> <span style=''>upon</span> <span style=''>marginal</span> <span style=''>likelihood</span> <span style=''>maximization</span> <span style=''>The</span> <span style=''>active</span> <span style=''>set</span> <span style=''>update</span> <span style=''>rules</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>predictive</span> <span style=''>distributions</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>classifier</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>relative</span> <span style=''>contribution</span> <span style=''>of</span> <span style=''>a</span> <span style=''>datapoint</span> <span style=''>when</span> <span style=''>being</span> <span style=''>either</span> <span style=''>included</span> <span style=''>or</span> <span style=''>removed</span> <span style=''>from</span> <span style=''>the</span> <span style=''>model</span> <span style=''>This</span> <span style=''>means</span> <span style=''>that</span> <span style=''>we</span> <span style=''>can</span> <span style=''>use</span> <span style=''>it</span> <span style=''>to</span> <span style=''>include</span> <span style=''>points</span> <span style=''>with</span> <span style=''>potentially</span> <span style=''>high</span> <span style=''>impact</span> <span style=''>to</span> <span style=''>the</span> <span style=''>classifier</span> <span style=''>decision</span> <span style=''>process</span> <span style=''>while</span> <span style=''>removing</span> <span style=''>those</span> <span style=''>that</span> <span style=''>are</span> <span style=''>less</span> <span style=''>relevant</span> <span style=''>We</span> <span style=''>introduce</span> <span style=''>two</span> <span style=''>active</span> <span style=''>set</span> <span style=''>rules</span> <span style=''>based</span> <span style=''>on</span> <span style=''>different</span> <span style=''>criteria</span> <span style=''>the</span> <span style=''>first</span> <span style=''>one</span> <span style=''>prefers</span> <span style=''>a</span> <span style=''>model</span> <span style=''>with</span> <span style=''>interpretable</span> <span style=''>active</span> <span style=''>set</span> <span style=''>parameters</span> <span style=''>whereas</span> <span style=''>the</span> <span style='' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	computationally (0.030663780663780664)
# 	regularization (0.02813852813852814)
# 	dimensionality (0.016955266955266956)
# 	generalization (0.04112554112554113)
# 	simultaneously (0.03463203463203463)
# 	classification (0.18975468975468976)
# 	implementation (0.046897546897546896)
# 	identification (0.03823953823953824)
# 	representations (0.08513708513708514)
# 	representation (0.12445887445887446)
#
# Some Statistics words are:
# 	representation (0.08211420481359132)
# 	representations (0.05474280320906088)
# 	identification (0.02784332232184993)
# 	implementation (0.037753657385559226)
# 	classification (0.18782444549315716)
# 	simultaneously (0.042000943841434636)
# 	generalization (0.06512505899008966)
# 	dimensionality (0.045304388862671074)
# 	regularization (0.06795658329400661)
# 	computationally (0.0736196319018405)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="625d8b75-469c-4b4a-a74a-a815d37a235d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("625d8b75-469c-4b4a-a74a-a815d37a235d")) {                    Plotly.newPlot(                        "625d8b75-469c-4b4a-a74a-a815d37a235d",                        [{"x":["classification","representations","implementation","representation","computationally","regularization","identification","generalization","dimensionality","simultaneously"],"y":[0.18975468975468976,0.08513708513708514,0.046897546897546896,0.12445887445887446,0.030663780663780664,0.02813852813852814,0.03823953823953824,0.04112554112554113,0.016955266955266956,0.03463203463203463],"type":"bar"},{"x":["classification","representations","implementation","representation","computationally","regularization","identification","generalization","dimensionality","simultaneously"],"y":[0.5692640692640693,0.6704545454545455,0.6190476190476191,0.6647398843930636,0.35269709543568467,0.3513513513513514,0.6424242424242426,0.45238095238095244,0.3286713286713287,0.518918918918919],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","lin ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
#
# Some words which never appear in Statistics papers:

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 0.01698521456905878

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.4897792313982011
